# %%
# Get Stats From Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read the values into out df to prepare for cleaning

import pandas as pd

file_path = '/content/drive/My Drive/lolfirststandstats.xlsx'
df = pd.read_excel(file_path, engine='openpyxl')

# %%
# Check to see if if the file was loaded correctly

df.head(5)
# Out:
#                   Name Season Region  Games  Win rate   K:D   GPM  GDM  \
# 0   CTBC Flying Oyster    S15     TW     13     0.615  1.12  1830    9
# 1  Hanwha Life eSports    S15     KR     17     0.824  1.89  2005  311
# 2         Karmine Corp    S15    EUW     19     0.421  0.86  1808  -68
# 3          Team Liquid    S15    NaN     10     0.300  0.67  1690 -235
# 4          Top Esports    S15     CN     11     0.182  0.58  1756 -159
#
#     Game duration  Kills / game  ...  TD@15  GD@15   PPG  NASHPG  NASH%   CSM  \
# 0 1 days 07:03:00          13.7  ...    0.1   -460  4.62    0.62   63.6  32.8
# 1 1 days 07:10:00          20.9  ...    0.1   1338  4.12    0.82   88.1  34.3
# 2 1 days 08:29:00          13.4  ...    0.0   -540  3.47    0.47   37.0  33.3
# 3 1 days 06:00:00          11.2  ...   -0.1   -315  2.80    0.20   28.6  31.7
# 4 1 days 06:26:00          11.7  ...   -0.1   -306  4.00    0.09   12.5  33.1
#
#     DPM  WPM  VWPM  WCPM
# 0  2593  3.6  1.51  1.45
# ...

# %%
# Check how many values in the dataframe are null
# Luckily only 1 Value is found

df.isnull().sum().sum()
# Out:
# 1

# %%
# Find where the null value is found

df.isnull().sum()
# Out:
# Name             0
# Season           0
# Region           1
# Games            0
# Win rate         0
# K:D              0
# GPM              0
# GDM              0
# Game duration    0
# Kills / game     0
# Deaths / game    0
# Towers killed    0
# Towers lost      0
# FB%              0
# FT%              0
# FOS%             0
# DRAPG            0
# DRA%             0
# VGPG             0
# HER%             0
# ATAKHAN%         0
# DRA@15           0
# TD@15            0
# GD@15            0
# PPG              0
# NASHPG           0
# NASH%            0
# CSM              0
# DPM              0
# WPM              0
# VWPM             0
# WCPM             0
# dtype: int64

# %%
df.loc[3, "Region"] = "NA"

# %%
# Check to see if if the file was loaded correctly

df.head(5)
# Out:
#                   Name Season Region  Games  Win rate   K:D   GPM  GDM  \
# 0   CTBC Flying Oyster    S15     TW     13     0.615  1.12  1830    9
# 1  Hanwha Life eSports    S15     KR     17     0.824  1.89  2005  311
# 2         Karmine Corp    S15    EUW     19     0.421  0.86  1808  -68
# 3          Team Liquid    S15     NA     10     0.300  0.67  1690 -235
# 4          Top Esports    S15     CN     11     0.182  0.58  1756 -159
#
#     Game duration  Kills / game  ...  TD@15  GD@15   PPG  NASHPG  NASH%   CSM  \
# 0 1 days 07:03:00          13.7  ...    0.1   -460  4.62    0.62   63.6  32.8
# 1 1 days 07:10:00          20.9  ...    0.1   1338  4.12    0.82   88.1  34.3
# 2 1 days 08:29:00          13.4  ...    0.0   -540  3.47    0.47   37.0  33.3
# 3 1 days 06:00:00          11.2  ...   -0.1   -315  2.80    0.20   28.6  31.7
# 4 1 days 06:26:00          11.7  ...   -0.1   -306  4.00    0.09   12.5  33.1
#
#     DPM  WPM  VWPM  WCPM
# 0  2593  3.6  1.51  1.45
# ...

# %%
df.to_csv('cleanedfirststandstats.csv', index=False)
